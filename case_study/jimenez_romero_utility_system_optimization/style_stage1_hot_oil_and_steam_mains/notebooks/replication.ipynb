# %% [markdown]
# # STYLE Stage 1 Hot-Oil And Steam-Main Replication
#
# Load the extracted Stage 1 benchmark fixtures as tables.

# %%
import pandas as pd

from case_study.jimenez_romero_utility_system_optimization.style_stage1_hot_oil_and_steam_mains import (
    STYLE_STAGE1_HOT_OIL_AND_STEAM_MAIN_DESIGN_RESULTS,
    STYLE_STAGE1_STEAM_SYSTEM_TARGETS,
)

# %%
steam_targets = pd.DataFrame(
    target.__dict__ for target in STYLE_STAGE1_STEAM_SYSTEM_TARGETS
)
hot_oil_results = pd.DataFrame(
    result.__dict__
    for result in STYLE_STAGE1_HOT_OIL_AND_STEAM_MAIN_DESIGN_RESULTS
)

steam_targets

# %%
hot_oil_results
